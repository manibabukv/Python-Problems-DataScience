# %%
#firstquestion-area of rectangle
length = 10.5
width = 5
area = length*width
print(area)
# Out:
# 52.5

# %%
#secondquestion-square of a number
number = int(input('Enter Number: '))
sqr_of_number = number**2
print(sqr_of_number)
# Out:
# Enter Number: 25
# 625

# %%
#thirdquestion-checking data types
obj1 = 9999.34
obj2 = 'informatics'
obj3 = 57687
obj4 = 'b501'
print(type(obj1))
print(type(obj2))
print(type(obj3))
print(type(obj4))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
#fourthquestion-divisibility check for 3 and 4
given_number = 96321
if given_number%3 == 0 and given_number%4 == 0:
    print('Divisible by 3 and 4')
elif given_number%3 == 0 and given_number%4 != 0:
    print('Divisible by 3 and not divisible by 4')
elif given_number%3 != 0 and given_number%4 == 0:
    print('Divisible by 4 and not divisible by 3')
else:
    print("Divisible by neither 3 nor 4")
# Out:
# Divisible by 3 and not divisible by 4
